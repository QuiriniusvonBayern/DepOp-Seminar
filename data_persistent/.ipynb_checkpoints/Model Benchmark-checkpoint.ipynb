# %% [markdown]
# <h2>Formating of DB-Data<h2>

# %%
from hilfsfunktionen.formating import get_unchanged_table, get_formated_table, get_table_with_keys, create_n_sentences
df_collection = {}
df_collection["unchanged_table"] = get_unchanged_table()
df_collection["formated_table"] = get_formated_table()
df_collection["formated_table_with_keys"] = get_table_with_keys(df_collection["formated_table"])
df_collection["n_sentences"] = {}
for n in [1, 5, 20, 50, 100]:
    df_collection["n_sentences"][f"{n}"] = create_n_sentences(df_collection["formated_table_with_keys"], n)

df_collection["formated_table_with_keys"].head
# Out:
# <bound method NDFrame.head of            key1            credit_score          country       key2  \
# 0         key_1       Credit_Score_Fair   Country_France      key_1
# 1         key_2       Credit_Score_Fair    Country_Spain      key_2
# 2         key_3       Credit_Score_Poor   Country_France      key_3
# 3         key_4       Credit_Score_Good   Country_France      key_4
# 4         key_5  Credit_Score_Excellent    Country_Spain      key_5
# ...         ...                     ...              ...        ...
# 9995   key_9996  Credit_Score_Very_Good   Country_France   key_9996
# 9996   key_9997       Credit_Score_Poor   Country_France   key_9997
# 9997   key_9998       Credit_Score_Good   Country_France   key_9998
# 9998   key_9999  Credit_Score_Very_Good  Country_Germany   key_9999
# 9999  key_10000  Credit_Score_Very_Good   Country_France  key_10000
#
#              gender                        age       key3     tenure  \
# 0     Gender_Female  Age_Adults_in_their_Prime      key_1   Tenure_2
# 1     Gender_Female  Age_Adults_in_their_Prime      key_2   Tenure_1
# 2     Gender_Female  Age_Adults_in_their_Prime      key_3   Tenure_8
# 3     Gender_Female  Age_Adults_in_their_Prime      key_4   Tenure_1
# 4     Gender_Female  Age_Adults_in_their_Prime      key_5   Tenure_2
# ...             ...                        ...        ...        ...
# 9995    Gender_Male  Age_Adults_in_their_Prime   key_9996   Tenure_5
# 9996    Gender_Male  Age_Adults_in_their_Prime   key_9997  Tenure_10
# 9997  Gender_Female  Age_Adults_in_their_Prime   key_9998   Tenure_7
# 9998    Gender_Male  Age_Adults_in_their_Prime   key_9999   Tenure_3
# 9999  Gender_Female           Age_Young_Adults  key_10000   Tenure_4
#
#                 balance       key4   products_number     credit_card  \
# 0     Balance_Cluster_1      key_1  ProductsNumber_1  CreditCard_Yes
# 1     Balance_Cluster_4      key_2  ProductsNumber_1   CreditCard_No
# 2     Balance_Cluster_7      key_3  ProductsNumber_3  CreditCard_Yes
# 3     Balance_Cluster_1      key_4  ProductsNumber_2   CreditCard_No
# 4     Balance_Cluster_6      key_5  ProductsNumber_1  CreditCard_Yes
# ...                 ...        ...               ...             ...
# 9995  Balance_Cluster_1   key_9996  ProductsNumber_2  CreditCard_Yes
# 9996  Balance_Cluster_3   key_9997  ProductsNumber_1  CreditCard_Yes
# 9997  Balance_Cluster_1   key_9998  ProductsNumber_1   CreditCard_No
# 9998  Balance_Cluster_3   key_9999  ProductsNumber_2  CreditCard_Yes
# 9999  Balance_Cluster_6  key_10000  ProductsNumber_1  CreditCard_Yes
#
#            key5     active_member      estimated_salary       key6      churn
# 0         key_1  ActiveMember_Yes           Salary_High      key_1  Churn_Yes
# 1         key_2  ActiveMember_Yes           Salary_High      key_2   Churn_No
# 2         key_3   ActiveMember_No           Salary_High      key_3  Churn_Yes
# 3         key_4   ActiveMember_No  Salary_Above_average      key_4   Churn_No
# 4         key_5  ActiveMember_Yes  Salary_Above_average      key_5   Churn_No
# ...         ...               ...                   ...        ...        ...
# 9995   key_9996   ActiveMember_No  Salary_Above_average   key_9996   Churn_No
# 9996   key_9997  ActiveMember_Yes           Salary_High   key_9997   Churn_No
# 9997   key_9998  ActiveMember_Yes        Salary_Average   key_9998  Churn_Yes
# 9998   key_9999   ActiveMember_No  Salary_Above_average   key_9999  Churn_Yes
# 9999  key_10000   ActiveMember_No        Salary_Average  key_10000   Churn_No
#
# [10000 rows x 17 columns]>

# %% [markdown]
# <h2>Model Creation<h2>

# %%
from hilfsfunktionen.model_training import (
    ModelConfig, 
    ModelTrainer, 
    ModelRepository, 
    ExperimentRunner
)
from pathlib import Path

seeds = [1, 42, 66]

trainer = ModelTrainer()
repository = ModelRepository(base_dir=Path.cwd())

models = {}  
categories = {} 

# Führe Experimente durch
for seed in seeds:
    base_config = ModelConfig(
        vector_size = 150,      # Dimension der Wortvektoren; guter Kompromiss zwischen Ausdrucksstärke und Rechenaufwand
        window = 4,             # Kleines Kontextfenster; betont lokale, eher syntaktische Beziehungen
        epochs = 30,            # Viele Trainingsdurchläufe; bessere Anpassung, aber erhöhtes Overfitting-Risiko
        min_count = 1,          # Alle Wörter werden berücksichtigt; seltene Wörter sind jedoch oft verrauscht
        negative = 5,           # Anzahl negativer Beispiele; Standardwert mit gutem Qualitäts-/Zeit-Verhältnis
        sample = 1e-3,             # Subsampling häufiger Wörter; verbessert Semantik, kann bei kleinen Korpora schaden
        hs = 0,                 # Hierarchical Softmax deaktiviert; Training erfolgt ausschließlich via Negative Sampling
        alpha = 0.025,          # Start-Lernrate; stabiler Trainingsbeginn, bei vielen Epochen kritisch
        seed = seed,               # Faester Zufallsstart; sorgt für Reproduzierbarkeit   
    )
    runner = ExperimentRunner(trainer, repository, base_config)
    models[seed], categories[seed] = runner.create_many_models(
        sentences=df_collection["n_sentences"]["20"],
        n_sentences_tokenized=df_collection["n_sentences"],
        n_used_sentences=10000, # Begrenzung der Trainingssätze; beschleunigt Training, limitiert Informationsgehalt
        verbose=True
    )
# Out:
# Model Creation started.
# ...Creating sentence models...
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_17_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_17_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_85_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_85_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_850_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_850_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_1700_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_1700_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# ...Finished Creating sentence models...
# ...Creating vector models...
# ...Creating vector_size models...
# Started Model-Creation with: CBOW, vs=20, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_20_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=20, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_20_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=30, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_30_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=30, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_30_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=40, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_40_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=40, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_40_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=60, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_60_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=60, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_60_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=80, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_80_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=80, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_80_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=120, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_120_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=120, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_120_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=140, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_140_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=140, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_140_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=160, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_160_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=160, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_160_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=180, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_180_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=180, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_180_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=225, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_225_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=225, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_225_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=250, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_250_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=250, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_250_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=275, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_275_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=275, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_275_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=350, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_350_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=350, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_350_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=400, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_400_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=400, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_400_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# ...Finished Creating vector_size models...
# ...Finished Creating vector models...
# ...Creating windowsize models...
# ...Creating window models...
# Started Model-Creation with: CBOW, vs=150, win=1, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_1_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=1, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_1_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=3, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_3_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=3, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_3_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=6, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_6_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=6, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_6_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=7, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_7_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=7, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_7_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=8, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_8_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=8, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_8_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=9, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_9_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=9, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_9_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=11, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_11_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=11, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_11_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=12, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_12_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=12, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_12_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=13, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_13_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=13, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_13_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=14, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_14_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=14, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_14_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=15, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_15_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=15, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_15_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=16, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_16_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=16, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_16_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=17, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_17_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=17, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_17_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=18, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_18_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=18, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_18_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# ...Finished Creating window models...
# ...Finished Creating windowsize models...
# ...Creating epoch models...
# ...Creating epochs models...
# Started Model-Creation with: CBOW, vs=150, win=4, ep=3
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_3_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=3
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_3_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=5
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_5_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=5
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_5_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=7
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_7_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=7
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_7_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=10
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_10_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=10
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_10_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=13
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_13_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=13
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_13_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=15
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_15_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=15
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_15_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=17
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_17_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=17
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_17_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=20
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_20_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=20
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_20_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=23
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_23_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=23
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_23_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=25
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_25_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=25
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_25_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=28
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_28_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=28
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_28_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=35
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_35_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=35
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_35_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=40
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_40_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=40
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_40_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=45
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_45_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=45
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_45_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=50
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_50_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=50
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_50_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=60
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_60_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=60
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_60_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=70
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_70_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=70
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_70_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=80
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_80_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=80
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_80_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=90
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_90_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=90
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_90_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=100
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_100_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=100
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_100_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=150
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_150_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=150
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_150_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=200
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_200_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=200
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_200_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# ...Finished Creating epochs models...
# ...Finished Creating epoch models...
# Model Creation finished.
# Model Creation started.
# ...Creating sentence models...
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_17_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_17_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_85_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_85_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_850_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_850_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_1700_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_1700_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# ...Finished Creating sentence models...
# ...Creating vector models...
# ...Creating vector_size models...
# Started Model-Creation with: CBOW, vs=20, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_20_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=20, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_20_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=30, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_30_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=30, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_30_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=40, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_40_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=40, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_40_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=60, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_60_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=60, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_60_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=80, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_80_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=80, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_80_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=120, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_120_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=120, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_120_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=140, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_140_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=140, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_140_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=160, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_160_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=160, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_160_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=180, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_180_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=180, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_180_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=225, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_225_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=225, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_225_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=250, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_250_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=250, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_250_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=275, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_275_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=275, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_275_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=350, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_350_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=350, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_350_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=400, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_400_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=400, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_400_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# ...Finished Creating vector_size models...
# ...Finished Creating vector models...
# ...Creating windowsize models...
# ...Creating window models...
# Started Model-Creation with: CBOW, vs=150, win=1, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_1_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=1, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_1_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=3, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_3_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=3, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_3_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=6, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_6_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=6, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_6_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=7, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_7_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=7, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_7_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=8, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_8_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=8, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_8_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=9, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_9_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=9, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_9_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=11, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_11_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=11, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_11_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=12, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_12_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=12, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_12_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=13, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_13_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=13, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_13_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=14, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_14_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=14, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_14_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=15, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_15_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=15, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_15_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=16, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_16_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=16, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_16_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=17, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_17_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=17, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_17_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=18, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_18_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=18, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_18_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# ...Finished Creating window models...
# ...Finished Creating windowsize models...
# ...Creating epoch models...
# ...Creating epochs models...
# Started Model-Creation with: CBOW, vs=150, win=4, ep=3
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_3_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=3
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_3_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=5
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_5_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=5
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_5_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=7
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_7_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=7
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_7_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=10
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_10_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=10
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_10_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=13
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_13_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=13
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_13_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=15
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_15_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=15
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_15_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=17
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_17_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=17
# ...
# Modell geladen: /workspace/models/CBOW_vs_150_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=6, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_6_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=6, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_6_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=7, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_7_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=7, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_7_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=8, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_8_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=8, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_8_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=9, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_9_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=9, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_9_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=11, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_11_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=11, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_11_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=12, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_12_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=12, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_12_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=13, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_13_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=13, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_13_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=14, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_14_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=14, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_14_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=15, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_15_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=15, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_15_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=16, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_16_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=16, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_16_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=17, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_17_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=17, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_17_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=18, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_18_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=18, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_18_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# ...Finished Creating window models...
# ...Finished Creating windowsize models...
# ...Creating epoch models...
# ...Creating epochs models...
# Started Model-Creation with: CBOW, vs=150, win=4, ep=3
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_3_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=3
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_3_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=5
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_5_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=5
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_5_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=7
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_7_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=7
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_7_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=10
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_10_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=10
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_10_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=13
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_13_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=13
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_13_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=15
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_15_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=15
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_15_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=17
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_17_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=17
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_17_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=20
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_20_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=20
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_20_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=23
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_23_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=23
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_23_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=25
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_25_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=25
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_25_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=28
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_28_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=28
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_28_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=30
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=35
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_35_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=35
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_35_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=40
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_40_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=40
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_40_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=45
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_45_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=45
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_45_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=50
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_50_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=50
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_50_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=60
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_60_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=60
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_60_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=70
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_70_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=70
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_70_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=80
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_80_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=80
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_80_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=90
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_90_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=90
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_90_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=100
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_100_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=100
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_100_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=150
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_150_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=150
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_150_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=150, win=4, ep=200
# Modell geladen: /workspace/models/CBOW_vs_150_win_4_ep_200_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=150, win=4, ep=200
# Modell geladen: /workspace/models/SGNS_vs_150_win_4_ep_200_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_66.model
# Loaded model.
# ...Finished Creating epochs models...
# ...Finished Creating epoch models...
# Model Creation finished.

# %% [markdown]
# <h2>Durchschnittliche Satzvektoren berechnen<h2>

# %%
from hilfsfunktionen.sentence_vectors import create_average_sentence_vectors

average_sentence_vectors = {}

for seed in seeds:
    if seed not in average_sentence_vectors:
        average_sentence_vectors[seed] = {}
    for category in categories[seed]:  
        print(f"(-------------Vector calculation of category: {category.upper()}-------------)")
        
        if category not in average_sentence_vectors[seed]:
            average_sentence_vectors[seed][category] = []
        
        for model in models[seed][category]:
            vectors = create_average_sentence_vectors(
                model, 
                df_collection["formated_table_with_keys"], 
                base_dir=Path.cwd(), 
                verbose=False
            )
            average_sentence_vectors[seed][category].append([vectors, model[1]])
        
        print(f"(-------------Finished Vector calculation of category: {category.upper()}-------------)")
# Out:
# (-------------Vector calculation of category: SENTENCE-------------)
# (-------------Finished Vector calculation of category: SENTENCE-------------)
# (-------------Vector calculation of category: VECTOR-------------)
# (-------------Finished Vector calculation of category: VECTOR-------------)
# (-------------Vector calculation of category: WINDOWSIZE-------------)
# (-------------Finished Vector calculation of category: WINDOWSIZE-------------)
# (-------------Vector calculation of category: EPOCH-------------)
# (-------------Finished Vector calculation of category: EPOCH-------------)
# (-------------Vector calculation of category: SENTENCE-------------)
# (-------------Finished Vector calculation of category: SENTENCE-------------)
# (-------------Vector calculation of category: VECTOR-------------)
# (-------------Finished Vector calculation of category: VECTOR-------------)
# (-------------Vector calculation of category: WINDOWSIZE-------------)
# (-------------Finished Vector calculation of category: WINDOWSIZE-------------)
# (-------------Vector calculation of category: EPOCH-------------)
# (-------------Finished Vector calculation of category: EPOCH-------------)
# (-------------Vector calculation of category: SENTENCE-------------)
# (-------------Finished Vector calculation of category: SENTENCE-------------)
# (-------------Vector calculation of category: VECTOR-------------)
# (-------------Finished Vector calculation of category: VECTOR-------------)
# (-------------Vector calculation of category: WINDOWSIZE-------------)
# (-------------Finished Vector calculation of category: WINDOWSIZE-------------)
# (-------------Vector calculation of category: EPOCH-------------)
# (-------------Finished Vector calculation of category: EPOCH-------------)

# %% [markdown]
# <h2>Vektoren-Test Textbasiert<h2>

# %% [markdown]
# <h2>Visualisierung<h2>
