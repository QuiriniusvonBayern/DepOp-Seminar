# %% [markdown]
# <h2>Formating of DB-Data<h2>

# %%
from hilfsfunktionen.formating import get_unchanged_table, get_formated_table, get_table_with_keys, create_n_sentences
df_collection = {}
df_collection["unchanged_table"] = get_unchanged_table()
df_collection["formated_table"] = get_formated_table()
df_collection["formated_table_with_keys"] = get_table_with_keys(df_collection["formated_table"])
df_collection["n_sentences"] = {}
for n in [1, 5, 20, 50, 100]:
    df_collection["n_sentences"][f"{n}"] = create_n_sentences(df_collection["formated_table_with_keys"], n)

# %% [markdown]
# <h2>Model Creation<h2>

# %%
from hilfsfunktionen.model_training import (
    ModelConfig, 
    ModelTrainer, 
    ModelRepository, 
    ExperimentRunner
)
from pathlib import Path
seeds = [1, 42]
models = {}  

for seed in seeds:
    base_config = ModelConfig(
        vector_size = 50,      # Dimension der Wortvektoren; guter Kompromiss zwischen Ausdrucksstärke und Rechenaufwand
        window = 4,             # Kleines Kontextfenster; betont lokale, eher syntaktische Beziehungen
        epochs = 30,            # Viele Trainingsdurchläufe; bessere Anpassung, aber erhöhtes Overfitting-Risiko
        min_count = 1,          # Alle Wörter werden berücksichtigt; seltene Wörter sind jedoch oft verrauscht
        negative = 5,           # Anzahl negativer Beispiele; Standardwert mit gutem Qualitäts-/Zeit-Verhältnis
        sample = 0,             # Subsampling häufiger Wörter; verbessert Semantik, kann bei kleinen Korpora schaden
        hs = 0,                 # Hierarchical Softmax deaktiviert; Training erfolgt ausschließlich via Negative Sampling
        alpha = 0.025,          # Start-Lernrate; stabiler Trainingsbeginn, bei vielen Epochen kritisch
        seed = 1,               # Faester Zufallsstart; sorgt für Reproduzierbarkeit   
    )
    
    PHASE_1_GRID = {
        "vector_size": [50, 100, 200, 300],
        "window": [2, 5, 10],
        "sg": [0, 1],
        "epochs": [30],
        "negative": [5],
        "sample": [1e-3],
        "hs": [0],
        "alpha": [0.025],
        "seed": [seed]
    }
    
    trainer = ModelTrainer()
    repository = ModelRepository(base_dir=Path.cwd())
    runner = ExperimentRunner(trainer, repository, base_config)
    
    
    models[seed]  = runner.run_grid_search(
        sentences=df_collection["n_sentences"]["20"],
        param_grid=PHASE_1_GRID,
        #n_sentences_tokenized=df_collection["n_sentences"],
        num_sentences=10000, # Begrenzung der Trainingssätze; beschleunigt Training, limitiert Informationsgehalt
        verbose=True
    )
# Out:
# Started Model-Creation with: CBOW, vs=50, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:01:40 2026
# Fertig um: Fri Jan 16 00:01:53 2026
# Nach: 0 Minuten und 13 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=50, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:01:53 2026
# Fertig um: Fri Jan 16 00:02:20 2026
# Nach: 0 Minuten und 27 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=50, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:02:20 2026
# Fertig um: Fri Jan 16 00:02:36 2026
# Nach: 0 Minuten und 15 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=50, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:02:36 2026
# Fertig um: Fri Jan 16 00:03:26 2026
# Nach: 0 Minuten und 49 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=50, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:03:26 2026
# Fertig um: Fri Jan 16 00:03:44 2026
# Nach: 0 Minuten und 17 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=50, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:03:44 2026
# Fertig um: Fri Jan 16 00:05:08 2026
# Nach: 1 Minuten und 24 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=100, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:05:08 2026
# Fertig um: Fri Jan 16 00:05:21 2026
# Nach: 0 Minuten und 12 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=100, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:05:21 2026
# Fertig um: Fri Jan 16 00:05:46 2026
# Nach: 0 Minuten und 25 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=100, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:05:46 2026
# Fertig um: Fri Jan 16 00:06:01 2026
# Nach: 0 Minuten und 14 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=100, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:06:01 2026
# Fertig um: Fri Jan 16 00:06:47 2026
# Nach: 0 Minuten und 46 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=100, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:06:47 2026
# Fertig um: Fri Jan 16 00:07:04 2026
# Nach: 0 Minuten und 17 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=100, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:07:05 2026
# Fertig um: Fri Jan 16 00:08:25 2026
# Nach: 1 Minuten und 20 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=200, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:08:25 2026
# Fertig um: Fri Jan 16 00:08:40 2026
# Nach: 0 Minuten und 15 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=200, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:08:40 2026
# Fertig um: Fri Jan 16 00:09:12 2026
# Nach: 0 Minuten und 31 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=200, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:09:12 2026
# Fertig um: Fri Jan 16 00:09:30 2026
# Nach: 0 Minuten und 18 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=200, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:09:30 2026
# Fertig um: Fri Jan 16 00:10:28 2026
# Nach: 0 Minuten und 58 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=200, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:10:28 2026
# Fertig um: Fri Jan 16 00:10:49 2026
# Nach: 0 Minuten und 21 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=200, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:10:49 2026
# Fertig um: Fri Jan 16 00:12:30 2026
# Nach: 1 Minuten und 40 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=300, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:12:30 2026
# Fertig um: Fri Jan 16 00:12:47 2026
# Nach: 0 Minuten und 17 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=300, win=2, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:12:47 2026
# Fertig um: Fri Jan 16 00:13:26 2026
# Nach: 0 Minuten und 38 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=300, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:13:26 2026
# Fertig um: Fri Jan 16 00:13:47 2026
# Nach: 0 Minuten und 20 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=300, win=5, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:13:47 2026
# Fertig um: Fri Jan 16 00:14:59 2026
# Nach: 1 Minuten und 12 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: CBOW, vs=300, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:14:59 2026
# Fertig um: Fri Jan 16 00:15:24 2026
# Nach: 0 Minuten und 25 Sekunden
# Modell gespeichert: /workspace/models/CBOW_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.
# Started Model-Creation with: SGNS, vs=300, win=10, ep=30
# Model has to be created new.
# Trainiere Modell mit 10000 Sätzen...
# Startzeit: Fri Jan 16 00:15:24 2026
# Fertig um: Fri Jan 16 00:17:28 2026
# Nach: 2 Minuten und 3 Sekunden
# Modell gespeichert: /workspace/models/SGNS_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0.001_hs_0_alpha_0.025_seed_42.model
# Created new model.

# %% [markdown]
# <h2>Durchschnittliche Satzvektoren berechnen<h2>

# %%
from hilfsfunktionen.sentence_vectors import create_average_sentence_vectors

average_sentence_vectors = {} 
for seed in seeds:
    average_sentence_vectors[seed] = []
    for model in models[seed]:
        average_sentence_vectors[seed].append([create_average_sentence_vectors(model, df_collection["formated_table_with_keys"], base_dir = Path.cwd(), verbose=False),model[1]])
    print("Finished for Seed: ", seed)
# Out:
# Finished for Seed:  1
# Finished for Seed:  42

# %% [markdown]
# <h2>Vektoren-Test Textbasiert<h2>

# %% [markdown]
# <h2>Visualisierung<h2>
