# %% [markdown]
# <h2>Formating of DB-Data<h2>

# %%
from hilfsfunktionen.formating import get_unchanged_table, get_formated_table, get_table_with_keys, create_n_sentences
df_collection = {}
df_collection["unchanged_table"] = get_unchanged_table()
df_collection["formated_table"] = get_formated_table()
df_collection["formated_table_with_keys"] = get_table_with_keys(df_collection["formated_table"])
df_collection["n_sentences"] = {}
for n in [1, 5, 20, 50, 100]:
    df_collection["n_sentences"][f"{n}"] = create_n_sentences(df_collection["formated_table_with_keys"], n)

# %% [markdown]
# <h2>Model Creation<h2>

# %%
from hilfsfunktionen.model_training import (
    ModelConfig, 
    ModelTrainer, 
    ModelRepository, 
    ExperimentRunner
)
from pathlib import Path
seeds = [1, 42]
models = {}  

for seed in seeds:
    base_config = ModelConfig(
        vector_size = 50,      # Dimension der Wortvektoren; guter Kompromiss zwischen Ausdrucksstärke und Rechenaufwand
        window = 4,             # Kleines Kontextfenster; betont lokale, eher syntaktische Beziehungen
        epochs = 30,            # Viele Trainingsdurchläufe; bessere Anpassung, aber erhöhtes Overfitting-Risiko
        min_count = 1,          # Alle Wörter werden berücksichtigt; seltene Wörter sind jedoch oft verrauscht
        negative = 5,           # Anzahl negativer Beispiele; Standardwert mit gutem Qualitäts-/Zeit-Verhältnis
        sample = 0,             # Subsampling häufiger Wörter; verbessert Semantik, kann bei kleinen Korpora schaden
        hs = 0,                 # Hierarchical Softmax deaktiviert; Training erfolgt ausschließlich via Negative Sampling
        alpha = 0.025,          # Start-Lernrate; stabiler Trainingsbeginn, bei vielen Epochen kritisch
        seed = seed,               # Faester Zufallsstart; sorgt für Reproduzierbarkeit   
    )
    
    GRID = {
        "vector_size": [50, 100, 150, 200, 300],
        "window": [2, 4, 6, 10, 15, 20],
        "sg": [0, 1],
        "epochs": [30],
        "negative": [5],
        "sample": [1e-3],
        "hs": [0],
        "alpha": [0.025],
        "seed": [seed]
    }
    
    trainer = ModelTrainer()
    repository = ModelRepository(base_dir=Path.cwd())
    runner = ExperimentRunner(trainer, repository, base_config)
    
    
    models[seed]  = runner.run_grid_search(
        sentences=df_collection["n_sentences"]["20"],
        param_grid=GRID,
        #n_sentences_tokenized=df_collection["n_sentences"],
        num_sentences=10000, # Begrenzung der Trainingssätze; beschleunigt Training, limitiert Informationsgehalt
        verbose=True
    )
# Out:
# Started Model-Creation with: CBOW, vs=50, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_1.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=50, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_50_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=50, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_50_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=100, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_100_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=100, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_100_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=200, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_200_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=200, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_200_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=2, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=2, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_2_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=5, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=5, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_5_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=10, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=10, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_10_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: CBOW, vs=300, win=20, ep=30
# Modell geladen: /workspace/models/CBOW_vs_300_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.
# Started Model-Creation with: SGNS, vs=300, win=20, ep=30
# Modell geladen: /workspace/models/SGNS_vs_300_win_20_ep_30_nsent_10000_sentlen_340_mc_1_neg_5_sample_0_hs_0_alpha_0.025_seed_42.model
# Loaded model.

# %% [markdown]
# <h2>Durchschnittliche Satzvektoren berechnen<h2>

# %%
from hilfsfunktionen.sentence_vectors import create_average_sentence_vectors

average_sentence_vectors = {} 
for seed in seeds:
    average_sentence_vectors[seed] = []
    for model in models[seed]:
        average_sentence_vectors[seed].append([create_average_sentence_vectors(model, df_collection["formated_table_with_keys"], base_dir = Path.cwd(), verbose=False),model[1]])
    print("Finished for Seed: ", seed)
# Out:
# Finished for Seed:  1
# Finished for Seed:  42

# %% [markdown]
# <h2>Vektoren-Test Textbasiert<h2>

# %%
from hilfsfunktionen.collect_test_data import get_all_grid_results
    
test_results = get_all_grid_results(average_sentence_vectors, models, df_collection["formated_table_with_keys"] , verbose=False)
# Out:
# Tests abgeschlossen. 32 Modelle getestet.

# %%
import pandas as pd
rows = []
print(test_results)
for r in test_results:
    p = r["params"]
    rows.append({
        "vector_size": p["Vector Size"],
        "window": p["Window"],
        "algorithm": p["Algorithmus"],
        "ssmq": r["ssmq"],
        "nd": r["nd_norm"],
        "rs": r["rs_mean"],
        "fc": r["fc"]
    })

df = pd.DataFrame(rows)
df.head
# Out:
# [{'params': {'Vector Size': 50, 'Window': 2, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.32651160086369296), 'rs_mean': np.float64(0.39638862482574155), 'rs_5': 0.41321428571428576, 'rs_10': 0.39493537078676405, 'rs_20': 0.3810162179761749, 'fc': 0.6843764091251886, 'kvc': {'model_score': np.float64(0.06520387486922809), 'avg_proximity_score': np.float64(0.3690909090909091), 'avg_weighted_proximity_score': np.float64(0.06520387486922809), 'total_found_values': 203, 'total_possible_values': 550, 'overall_recall': 0.3690909090909091, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 2, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [1.0980413, 0.90483165, 6.205904, 5.2760015, 1...
# 1         1      Key_2  [0.6242651, 1.0381473, 3.029513, 5.5712023, 0....
# 2         2      Key_3  [2.5831993, 1.561238, 3.5140321, 4.0955935, 1....
# 3         3      Key_4  [-1.351488, 0.028917588, 4.226379, 5.0053697, ...
# 4         4      Key_5  [-0.18531652, 0.16382986, 3.3024027, 5.879577,...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-1.7197591, 1.0181266, 4.0648646, 4.5021415, ...
# 9996   9996   Key_9997  [-0.89897096, 2.2943807, 4.6024704, 4.8328443,...
# 9997   9997   Key_9998  [1.1030993, 0.5397006, 4.442091, 5.029773, -0....
# 9998   9998   Key_9999  [0.2633842, 2.6163607, 2.9978578, 2.516214, 1....
# 9999   9999  Key_10000  [1.1176459, 0.24891758, 4.655212, 4.695331, 1....
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [3.3691137, -1.436921, 1.9175488, -4.186781, -...
# 1         1      Key_2  [2.4683988, -0.52957606, 1.8204464, -3.4435937...
# 2         2      Key_3  [2.4077578, -2.364177, 0.87843764, -4.7687716,...
# 3         3      Key_4  [1.9492645, -1.1055578, 2.8177788, -2.5342557,...
# 4         4      Key_5  [4.266175, 0.42382196, 3.3190002, -2.9941056, ...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [2.3603144, 0.12755391, 3.1765387, -2.604918, ...
# 9996   9996   Key_9997  [2.3188882, -1.342889, 3.0119615, -3.4440958, ...
# 9997   9997   Key_9998  [4.4665313, -1.7876254, 1.9543117, -3.163598, ...
# 9998   9998   Key_9999  [3.0295014, -1.4751624, 2.537668, -4.3073773, ...
# 9999   9999  Key_10000  [4.2176943, -2.0661333, 2.394311, -0.43715122,...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf7c8590>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 2, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '20b3b2609b', 'nd_norm': np.float64(0.32651160086369296), 'ssmq': np.float64(0.41904766970460666), 'summary': {'vector_size': 50, 'algorithm': 'CBOW', 'window': 2, 'epochs': 30, 'seed': 1, 'nd_score': 0.32651160086369296, 'rs_mean_score': 0.39638862482574155, 'fc_score': 0.6843764091251886, 'ssmq_score': 0.41904766970460666, 'kvc_recall': 0.3690909090909091}}, {'params': {'Vector Size': 50, 'Window': 2, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.2787900927186467), 'rs_mean': np.float64(0.7130038040327897), 'rs_5': 0.718214285714286, 'rs_10': 0.7195396270396271, 'rs_20': 0.7012574993444559, 'fc': 0.7078438241758241, 'kvc': {'model_score': np.float64(0.05842970382964754), 'avg_proximity_score': np.float64(0.3454545454545454), 'avg_weighted_proximity_score': np.float64(0.05842970382964754), 'total_found_values': 190, 'total_possible_values': 550, 'overall_recall': 0.34545454545454546, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 2, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [0.04167871, -0.016741045, -0.38088417, -0.471...
# 1         1      Key_2  [-0.45663977, 0.17055541, -0.6604923, -0.80525...
# 2         2      Key_3  [0.03128431, 0.83344954, -0.2851557, -0.589265...
# 3         3      Key_4  [-0.29394102, 0.47047412, -0.6486035, -0.50763...
# 4         4      Key_5  [-0.0780291, 0.13828298, -0.5425692, -0.778359...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.033694446, 0.290434, -0.207656, -0.7131913...
# 9996   9996   Key_9997  [-0.070555754, 0.7789716, -0.053911265, -0.694...
# 9997   9997   Key_9998  [-0.18343602, 0.2055584, -0.37486994, -0.60756...
# 9998   9998   Key_9999  [-0.31821612, 0.40489447, -0.39406216, -0.7618...
# 9999   9999  Key_10000  [0.11145943, 0.6689734, -0.45645475, -0.768897...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [0.40831363, -0.388138, -0.24819563, 0.376629,...
# 1         1      Key_2  [0.48074514, -0.27251062, -0.68295795, 0.46150...
# 2         2      Key_3  [0.02430019, 0.17273813, 0.17924134, 0.5129633...
# 3         3      Key_4  [0.086970724, -0.4923091, -0.42163846, 0.36311...
# 4         4      Key_5  [-0.035491373, -0.7316643, -0.35464156, 0.4468...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.16083597, -0.4469714, 0.20418788, 0.014943...
# 9996   9996   Key_9997  [-0.111926794, -0.49026805, 0.10272468, 0.1189...
# 9997   9997   Key_9998  [0.3063977, -0.22715308, -0.22875533, 0.470927...
# 9998   9998   Key_9999  [-0.44752902, 0.030370068, 0.2918287, 0.376047...
# 9999   9999  Key_10000  [0.15522528, -0.46005204, -0.041514453, 0.0963...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceb04b0890>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 2, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'd2e38ef6d6', 'nd_norm': np.float64(0.2787900927186467), 'ssmq': np.float64(0.4948649524043251), 'summary': {'vector_size': 50, 'algorithm': 'SGNS', 'window': 2, 'epochs': 30, 'seed': 1, 'nd_score': 0.2787900927186467, 'rs_mean_score': 0.7130038040327897, 'fc_score': 0.7078438241758241, 'ssmq_score': 0.4948649524043251, 'kvc_recall': 0.34545454545454546}}, {'params': {'Vector Size': 50, 'Window': 5, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.36600970403481575), 'rs_mean': np.float64(0.19848670179529146), 'rs_5': 0.17936507936507937, 'rs_10': 0.2051888720154974, 'rs_20': 0.2109061540052975, 'fc': 0.6973969052108023, 'kvc': {'model_score': np.float64(0.08384765495629555), 'avg_proximity_score': np.float64(0.42363636363636364), 'avg_weighted_proximity_score': np.float64(0.08384765495629555), 'total_found_values': 233, 'total_possible_values': 550, 'overall_recall': 0.42363636363636364, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 5, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [2.3259737, -2.6428318, -0.86292547, 3.6344888...
# 1         1      Key_2  [0.8995764, -2.3454607, -0.8495524, 3.3179727,...
# 2         2      Key_3  [0.5349972, -1.5358831, 0.8079992, 4.8343234, ...
# 3         3      Key_4  [2.4214334, -4.8482914, -2.8461733, 3.8866441,...
# 4         4      Key_5  [0.83985, -1.2006358, -3.8457086, 4.8521, 0.49...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.77371144, -2.4333591, -5.354739, 5.379259, ...
# 9996   9996   Key_9997  [1.7576079, -1.7643834, -1.030939, 3.7133446, ...
# 9997   9997   Key_9998  [3.4604158, -3.8940923, -1.5232517, 3.1672883,...
# 9998   9998   Key_9999  [-2.0893862, -0.4244584, -3.4185393, 5.309866,...
# 9999   9999  Key_10000  [1.365506, -5.008573, -4.34622, 6.579063, -0.0...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [4.7877684, 0.8835484, -1.3802081, 1.8465031, ...
# 1         1      Key_2  [5.710966, 1.0311829, -0.5102345, -0.66701776,...
# 2         2      Key_3  [3.0572703, 3.3090806, -0.036187258, 2.229799,...
# 3         3      Key_4  [4.850524, 4.156591, -1.8801963, -0.5556303, 1...
# 4         4      Key_5  [6.1635365, 0.572378, -0.49013278, 1.7573451, ...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [2.9828644, 3.5427537, -2.36333, 1.0072573, 3....
# 9996   9996   Key_9997  [3.9153779, 2.7772272, -0.85136586, 2.8480828,...
# 9997   9997   Key_9998  [4.340886, 1.4846954, -2.185012, 1.6665359, 1....
# 9998   9998   Key_9999  [2.254849, 3.6303403, -2.1595805, 3.5949519, 2...
# 9999   9999  Key_10000  [3.8863082, 3.1098588, -0.572628, 1.8661239, 3...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf4e3190>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 5, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'b5301b60e6', 'nd_norm': np.float64(0.36600970403481575), 'ssmq': np.float64(0.3820302435981558), 'summary': {'vector_size': 50, 'algorithm': 'CBOW', 'window': 5, 'epochs': 30, 'seed': 1, 'nd_score': 0.36600970403481575, 'rs_mean_score': 0.19848670179529146, 'fc_score': 0.6973969052108023, 'ssmq_score': 0.3820302435981558, 'kvc_recall': 0.42363636363636364}}, {'params': {'Vector Size': 50, 'Window': 5, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.120848103583367), 'rs_mean': np.float64(0.5510690511648756), 'rs_5': 0.5617460317460319, 'rs_10': 0.5509827710988702, 'rs_20': 0.5404783506497247, 'fc': 0.6851077740249946, 'kvc': {'model_score': np.float64(0.05111172741478117), 'avg_proximity_score': np.float64(0.36), 'avg_weighted_proximity_score': np.float64(0.05111172741478117), 'total_found_values': 198, 'total_possible_values': 550, 'overall_recall': 0.36, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 5, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [-0.7130813, -0.645883, 1.1187793, -0.35846958...
# 1         1      Key_2  [-0.75377613, -0.71010303, 1.0296607, -0.43940...
# 2         2      Key_3  [-0.72114176, -0.17465515, 1.2169583, 0.016715...
# 3         3      Key_4  [-0.6257798, -0.5556498, 1.0285925, -0.1880594...
# 4         4      Key_5  [-0.7999513, -0.56335545, 0.9727487, -0.693037...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.86426795, -0.45132005, 1.057804, -0.309521...
# 9996   9996   Key_9997  [-0.91089094, -0.36579582, 1.1391538, -0.33836...
# 9997   9997   Key_9998  [-0.7687064, -0.4160647, 1.278968, -0.4463788,...
# 9998   9998   Key_9999  [-0.90579414, -0.3993284, 1.0601763, -0.454325...
# 9999   9999  Key_10000  [-0.71645886, -0.33564216, 0.96822107, -0.5871...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [0.15315133, 0.0434271, -0.8928484, -0.5136261...
# 1         1      Key_2  [0.26879868, 0.29183754, -1.0544424, -0.545406...
# 2         2      Key_3  [0.21748348, 0.20449643, -0.95919824, -0.17752...
# 3         3      Key_4  [0.15996419, 0.26351044, -0.99060255, -0.28371...
# 4         4      Key_5  [0.28149942, 0.5433361, -0.98528886, -0.450784...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.06517825, 0.2675586, -0.81268805, -0.37984...
# 9996   9996   Key_9997  [0.28672352, 0.19314532, -0.79179764, -0.37199...
# 9997   9997   Key_9998  [0.15442501, -0.21026205, -1.0537108, -0.34669...
# 9998   9998   Key_9999  [-0.11723538, 0.37607697, -0.82107943, -0.4454...
# 9999   9999  Key_10000  [0.09928283, 0.15384772, -0.91072726, -0.61754...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaef82e90>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 5, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'c20cbbe1fa', 'nd_norm': np.float64(0.120848103583367), 'ssmq': np.float64(0.3627663219461451), 'summary': {'vector_size': 50, 'algorithm': 'SGNS', 'window': 5, 'epochs': 30, 'seed': 1, 'nd_score': 0.120848103583367, 'rs_mean_score': 0.5510690511648756, 'fc_score': 0.6851077740249946, 'ssmq_score': 0.3627663219461451, 'kvc_recall': 0.36}}, {'params': {'Vector Size': 50, 'Window': 10, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.6704395588775353), 'rs_mean': np.float64(0.39399689260226767), 'rs_5': 0.40182539682539675, 'rs_10': 0.4014898946942291, 'rs_20': 0.3786753862871772, 'fc': 0.6777512304138928, 'kvc': {'model_score': np.float64(0.07628035965504303), 'avg_proximity_score': np.float64(0.36727272727272736), 'avg_weighted_proximity_score': np.float64(0.07628035965504303), 'total_found_values': 202, 'total_possible_values': 550, 'overall_recall': 0.36727272727272725, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 10, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [4.389585, 4.21349, -6.234246, 0.22556569, 2.6...
# 1         1      Key_2  [1.9431328, 4.478234, -0.44951078, -3.455149, ...
# 2         2      Key_3  [1.7486492, 3.5805328, -2.712979, -0.28117558,...
# 3         3      Key_4  [0.65147746, 2.9808748, -0.14238244, -2.625902...
# 4         4      Key_5  [3.2980347, 1.8662509, -3.4477148, -0.38816592...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [1.0412446, 0.28980437, -4.1247272, -1.1964864...
# 9996   9996   Key_9997  [3.1100762, 1.422248, -2.7371752, -1.2018158, ...
# 9997   9997   Key_9998  [0.6006954, 2.4673743, -2.3943148, -2.021935, ...
# 9998   9998   Key_9999  [2.6406617, 0.7528808, -3.723838, -3.2556531, ...
# 9999   9999  Key_10000  [2.099052, 0.72125113, 0.04434733, 2.61172, 2....
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [3.1892478, -2.3163316, -3.7887, 2.671478, 2.4...
# 1         1      Key_2  [-1.718324, -2.6245806, 1.175473, -0.49032125,...
# 2         2      Key_3  [-1.1510519, -3.2692149, -3.0423973, -0.194235...
# 3         3      Key_4  [-2.340882, 1.4654742, -1.8495667, -0.7412184,...
# 4         4      Key_5  [0.5494353, -0.89262086, 0.28215373, 2.2860181...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-3.3149183, -1.2143174, -2.4844894, 1.0147942...
# 9996   9996   Key_9997  [-1.044035, -4.292747, -2.5791526, 2.4414308, ...
# 9997   9997   Key_9998  [2.0938044, -1.1076636, -1.6360859, 0.9375759,...
# 9998   9998   Key_9999  [-2.065709, -1.1992524, -2.3599985, -1.6672145...
# 9999   9999  Key_10000  [0.7657873, -0.42096856, -1.4909401, 4.8196187...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf7413d0>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 10, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '1280f371b2', 'nd_norm': np.float64(0.6704395588775353), 'ssmq': np.float64(0.5889690933022265), 'summary': {'vector_size': 50, 'algorithm': 'CBOW', 'window': 10, 'epochs': 30, 'seed': 1, 'nd_score': 0.6704395588775353, 'rs_mean_score': 0.39399689260226767, 'fc_score': 0.6777512304138928, 'ssmq_score': 0.5889690933022265, 'kvc_recall': 0.36727272727272725}}, {'params': {'Vector Size': 50, 'Window': 10, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.03928128571285011), 'rs_mean': np.float64(0.4736232569301333), 'rs_5': 0.5024206349206349, 'rs_10': 0.46100457935597255, 'rs_20': 0.4574445565137924, 'fc': 0.6652150588140788, 'kvc': {'model_score': np.float64(0.046512707528891035), 'avg_proximity_score': np.float64(0.32727272727272727), 'avg_weighted_proximity_score': np.float64(0.046512707528891035), 'total_found_values': 180, 'total_possible_values': 550, 'overall_recall': 0.32727272727272727, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 10, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [0.14103286, 0.07409592, 0.34630856, -0.086544...
# 1         1      Key_2  [0.14447522, 0.08268228, 0.37428027, -0.024468...
# 2         2      Key_3  [0.18689236, 0.04530142, 0.41598317, -0.080961...
# 3         3      Key_4  [0.13060912, 0.065793216, 0.41477844, -0.09128...
# 4         4      Key_5  [0.017802993, 0.27759057, 0.43355748, -0.13731...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.15747996, 0.183741, 0.41641867, -0.17903553...
# 9996   9996   Key_9997  [0.08984749, 0.11762183, 0.38424045, -0.078223...
# 9997   9997   Key_9998  [0.12044702, 0.085763216, 0.2890587, -0.177565...
# 9998   9998   Key_9999  [0.06832972, 0.19700341, 0.41144407, -0.152344...
# 9999   9999  Key_10000  [0.17257339, 0.22342862, 0.47924662, 0.0050493...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [0.6798448, 0.6067016, -0.65553474, -0.3040511...
# 1         1      Key_2  [0.62289405, 0.56285816, -0.57745016, -0.23090...
# 2         2      Key_3  [0.50358397, 0.53542113, -0.5255309, -0.331808...
# 3         3      Key_4  [0.58500403, 0.53424984, -0.68500423, -0.30252...
# 4         4      Key_5  [0.5172172, 0.6248003, -0.72030824, -0.2341674...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.63230205, 0.5454069, -0.67395854, -0.261052...
# 9996   9996   Key_9997  [0.47618276, 0.5877129, -0.59021074, -0.201413...
# 9997   9997   Key_9998  [0.6247539, 0.68642426, -0.7073923, -0.2630108...
# 9998   9998   Key_9999  [0.50050503, 0.54237986, -0.55958945, -0.36966...
# 9999   9999  Key_10000  [0.60282606, 0.6454186, -0.7029062, -0.2336204...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf1bb310>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 10, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'ea26f1ac12', 'nd_norm': np.float64(0.03928128571285011), 'ssmq': np.float64(0.29477063169828077), 'summary': {'vector_size': 50, 'algorithm': 'SGNS', 'window': 10, 'epochs': 30, 'seed': 1, 'nd_score': 0.03928128571285011, 'rs_mean_score': 0.4736232569301333, 'fc_score': 0.6652150588140788, 'ssmq_score': 0.29477063169828077, 'kvc_recall': 0.32727272727272727}}, {'params': {'Vector Size': 50, 'Window': 20, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(1.0), 'rs_mean': np.float64(0.7398089705563469), 'rs_5': 0.7265476190476191, 'rs_10': 0.7595004995004996, 'rs_20': 0.7333787931209218, 'fc': 0.7200199347662141, 'kvc': {'model_score': np.float64(0.0648467005209195), 'avg_proximity_score': np.float64(0.36), 'avg_weighted_proximity_score': np.float64(0.0648467005209195), 'total_found_values': 198, 'total_possible_values': 550, 'overall_recall': 0.36, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 20, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [0.3870409, -7.634387, 2.5642374, -0.043827534...
# 1         1      Key_2  [12.530501, 1.4771194, -4.278946, -5.661375, 2...
# 2         2      Key_3  [10.8996525, -10.194917, 0.37827232, 2.5814512...
# 3         3      Key_4  [5.0774555, -7.97599, -7.787882, -19.098146, 3...
# 4         4      Key_5  [4.0665364, -1.2316489, 4.6609144, 13.595638, ...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [2.4019256, -7.4330277, 10.1722555, -7.421971,...
# 9996   9996   Key_9997  [11.604229, 0.26247683, 4.0375066, 4.170947, -...
# 9997   9997   Key_9998  [1.6233642, -7.023872, -15.221219, -1.3909949,...
# 9998   9998   Key_9999  [4.559688, -9.708091, 6.004123, 9.849314, 5.80...
# 9999   9999  Key_10000  [-2.2130194, 5.2162585, 3.5227141, 1.0701089, ...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [1.1411022, 12.8911495, -6.3726573, -9.866619,...
# 1         1      Key_2  [3.4678552, 11.091155, -9.216112, -6.992314, -...
# 2         2      Key_3  [16.281221, 10.621741, -3.9747558, 0.39456558,...
# 3         3      Key_4  [-2.9644282, 27.836458, 4.9322033, 7.3975677, ...
# 4         4      Key_5  [-11.883256, 6.514532, -10.590733, -6.6775084,...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [1.7103417, 27.127098, 17.897076, -0.4619626, ...
# 9996   9996   Key_9997  [-1.6931735, 16.22248, 0.39926338, -4.271555, ...
# 9997   9997   Key_9998  [2.4713514, 19.063026, -4.804325, 1.2188205, -...
# 9998   9998   Key_9999  [4.8637257, 16.09803, 8.947625, -7.485768, -12...
# 9999   9999  Key_10000  [4.0478587, 18.059519, -1.1236491, -14.175343,...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf4af390>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 20, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '4785782bb8', 'nd_norm': np.float64(1.0), 'ssmq': np.float64(0.8659466781201468), 'summary': {'vector_size': 50, 'algorithm': 'CBOW', 'window': 20, 'epochs': 30, 'seed': 1, 'nd_score': 1.0, 'rs_mean_score': 0.7398089705563469, 'fc_score': 0.7200199347662141, 'ssmq_score': 0.8659466781201468, 'kvc_recall': 0.36}}, {'params': {'Vector Size': 50, 'Window': 20, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.0), 'rs_mean': np.float64(0.4817960013690792), 'rs_5': 0.5195238095238095, 'rs_10': 0.4871856738033209, 'rs_20': 0.43867852078010705, 'fc': 0.6628282857794939, 'kvc': {'model_score': np.float64(0.048436364547045654), 'avg_proximity_score': np.float64(0.3818181818181818), 'avg_weighted_proximity_score': np.float64(0.048436364547045654), 'total_found_values': 210, 'total_possible_values': 550, 'overall_recall': 0.38181818181818183, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 50, 'Window': 20, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [-0.026099974, -0.30331275, 0.49833724, 0.1336...
# 1         1      Key_2  [-0.12458151, -0.2766432, 0.52788806, 0.250442...
# 2         2      Key_3  [-0.13015176, -0.1660986, 0.4404039, 0.2008995...
# 3         3      Key_4  [-0.006968606, -0.2999648, 0.5900307, 0.230010...
# 4         4      Key_5  [-0.009089927, -0.2788766, 0.5194987, 0.112606...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.09803705, -0.27782428, 0.57362014, 0.112262...
# 9996   9996   Key_9997  [-0.076675005, -0.3269151, 0.501337, 0.0448515...
# 9997   9997   Key_9998  [0.014773384, -0.25305697, 0.50351626, 0.12191...
# 9998   9998   Key_9999  [0.08170927, -0.1617229, 0.54202706, 0.0348667...
# 9999   9999  Key_10000  [0.012390004, -0.13834766, 0.5381096, 0.061914...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [0.42843124, -0.05505296, 0.3846322, 0.4089195...
# 1         1      Key_2  [0.43736503, -0.13786246, 0.37671554, 0.397686...
# 2         2      Key_3  [0.36125997, -0.10121303, 0.393289, 0.37210426...
# 3         3      Key_4  [0.4936115, -0.02162558, 0.40762246, 0.3046243...
# 4         4      Key_5  [0.3129176, -0.070557006, 0.35209346, 0.428052...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.5082494, 0.029291676, 0.3313467, 0.31613487...
# 9996   9996   Key_9997  [0.4476546, 0.023358326, 0.17521454, 0.4131935...
# 9997   9997   Key_9998  [0.4220272, -0.024363793, 0.33652508, 0.338176...
# 9998   9998   Key_9999  [0.4051695, 0.01590436, 0.35110274, 0.37953988...
# 9999   9999  Key_10000  [0.40767562, 0.013088462, 0.36485317, 0.403329...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf210a50>, 'model_config_with_seed': {'Vector Size': 50, 'Window': 20, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '6f2f88c31e', 'nd_norm': np.float64(0.0), 'ssmq': np.float64(0.27710445756662255), 'summary': {'vector_size': 50, 'algorithm': 'SGNS', 'window': 20, 'epochs': 30, 'seed': 1, 'nd_score': 0.0, 'rs_mean_score': 0.4817960013690792, 'fc_score': 0.6628282857794939, 'ssmq_score': 0.27710445756662255, 'kvc_recall': 0.38181818181818183}}, {'params': {'Vector Size': 100, 'Window': 2, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.3743513928935175), 'rs_mean': np.float64(0.6446467156121846), 'rs_5': 0.663809523809524, 'rs_10': 0.6339377289377289, 'rs_20': 0.6361928940893007, 'fc': 0.6922689020146521, 'kvc': {'model_score': np.float64(0.058406477978037226), 'avg_proximity_score': np.float64(0.34), 'avg_weighted_proximity_score': np.float64(0.058406477978037226), 'total_found_values': 187, 'total_possible_values': 550, 'overall_recall': 0.34, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 100, 'Window': 2, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [-1.7184448, 2.973607, 0.87703, -0.14673974, 0...
# 1         1      Key_2  [0.13983832, 3.1968567, 1.0051055, -0.01881408...
# 2         2      Key_3  [-2.7482243, 3.6972694, 0.46010572, 0.5206603,...
# 3         3      Key_4  [-1.4222373, 3.1611178, 1.4420788, -1.1064756,...
# 4         4      Key_5  [-0.2686065, 3.7086692, 1.6323391, -1.1605856,...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-1.0040511, 3.5500014, 2.716173, -0.73891664,...
# 9996   9996   Key_9997  [-1.6531513, 3.8299196, 2.2123246, 0.015882146...
# 9997   9997   Key_9998  [-1.4569722, 2.6583657, 0.44592807, -0.1371516...
# 9998   9998   Key_9999  [-1.0375816, 2.9654462, 1.5456786, 0.12988581,...
# 9999   9999  Key_10000  [-0.29763463, 3.9986162, 1.8371106, -0.1995981...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [3.6778038, 0.15147363, 0.9235283, 1.4697624, ...
# 1         1      Key_2  [2.6879983, 1.170114, -0.08664422, 1.9938538, ...
# 2         2      Key_3  [4.8986955, -0.1412969, 0.09614429, 0.63257843...
# 3         3      Key_4  [3.011173, 0.3279316, 1.0280213, -0.39864072, ...
# 4         4      Key_5  [3.7541535, 1.1161004, -0.06020585, 0.7320757,...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [3.5122688, 0.3868803, 1.0630181, 1.081502, 1....
# 9996   9996   Key_9997  [4.350484, 0.24943218, -0.02450297, 1.9852458,...
# 9997   9997   Key_9998  [4.123369, 0.91535664, 1.5051358, 0.90053076, ...
# 9998   9998   Key_9999  [3.2096786, -0.99207425, 0.6377483, -0.4288619...
# 9999   9999  Key_10000  [3.3468728, 1.4116176, 2.0030231, 2.6525247, 0...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaea29e90>, 'model_config_with_seed': {'Vector Size': 100, 'Window': 2, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'b6a7103f9d', 'nd_norm': np.float64(0.3743513928935175), 'ssmq': np.float64(0.5190234915333445), 'summary': {'vector_size': 100, 'algorithm': 'CBOW', 'window': 2, 'epochs': 30, 'seed': 1, 'nd_score': 0.3743513928935175, 'rs_mean_score': 0.6446467156121846, 'fc_score': 0.6922689020146521, 'ssmq_score': 0.5190234915333445, 'kvc_recall': 0.34}}, {'params': {'Vector Size': 100, 'Window': 2, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.3880143819501841), 'rs_mean': np.float64(0.8249947540382324), 'rs_5': 0.7909523809523811, 'rs_10': 0.8447519147519148, 'rs_20': 0.8392799664104013, 'fc': 0.7198302481684983, 'kvc': {'model_score': np.float64(0.06199190098296487), 'avg_proximity_score': np.float64(0.37090909090909085), 'avg_weighted_proximity_score': np.float64(0.06199190098296487), 'total_found_values': 204, 'total_possible_values': 550, 'overall_recall': 0.3709090909090909, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 100, 'Window': 2, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [-0.2241053, -0.2869806, -0.42112446, 0.266470...
# 1         1      Key_2  [-0.39540014, -0.2950759, -0.18339816, 0.51345...
# 2         2      Key_3  [0.06761809, -0.3782814, -0.22681785, 0.352692...
# 3         3      Key_4  [-0.38946864, -0.17227645, -0.01423522, 0.2265...
# 4         4      Key_5  [-0.20254603, -0.1354591, -0.36284402, 0.44747...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.31724328, -0.22012635, -0.2255798, 0.48819...
# 9996   9996   Key_9997  [-0.38597316, -0.26457444, -0.2467549, 0.59258...
# 9997   9997   Key_9998  [-0.110969566, -0.038726285, -0.3005561, -0.22...
# 9998   9998   Key_9999  [0.06432859, -0.49910298, 0.07475068, 0.609410...
# 9999   9999  Key_10000  [-0.1575528, -0.010394082, -0.526266, 0.526409...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [0.3526913, -0.42442, 0.26886103, 0.40263665, ...
# 1         1      Key_2  [0.20386915, -0.50114036, 0.3507439, 0.3698111...
# 2         2      Key_3  [0.20747629, -0.5552492, 0.044037476, 0.289994...
# 3         3      Key_4  [0.25302517, -0.66821456, 0.3370396, 0.0929055...
# 4         4      Key_5  [0.36169317, -0.47812507, 0.14838304, 0.473741...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.27010825, -0.7400776, 0.21669874, 0.344316,...
# 9996   9996   Key_9997  [0.07839885, -0.46699044, 0.42074853, 0.440536...
# 9997   9997   Key_9998  [0.07869118, -0.2905382, 0.48252028, 0.4302220...
# 9998   9998   Key_9999  [0.47181433, -0.5843943, 0.23139648, 0.4749984...
# 9999   9999  Key_10000  [0.098745294, -0.60163283, 0.069464795, 0.2713...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaef82dd0>, 'model_config_with_seed': {'Vector Size': 100, 'Window': 2, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '861f981e46', 'nd_norm': np.float64(0.3880143819501841), 'ssmq': np.float64(0.5854716668202614), 'summary': {'vector_size': 100, 'algorithm': 'SGNS', 'window': 2, 'epochs': 30, 'seed': 1, 'nd_score': 0.3880143819501841, 'rs_mean_score': 0.8249947540382324, 'fc_score': 0.7198302481684983, 'ssmq_score': 0.5854716668202614, 'kvc_recall': 0.3709090909090909}}, {'params': {'Vector Size': 100, 'Window': 5, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.9685490223141822), 'rs_mean': np.float64(0.35775381511727994), 'rs_5': 0.3626587301587302, 'rs_10': 0.3580990741284859, 'rs_20': 0.3525036410646239, 'fc': 0.700611997306615, 'kvc': {'model_score': np.float64(0.08023804179215098), 'avg_proximity_score': np.float64(0.39272727272727265), 'avg_weighted_proximity_score': np.float64(0.08023804179215098), 'total_found_values': 216, 'total_possible_values': 550, 'overall_recall': 0.3927272727272727, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 100, 'Window': 5, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [1.6431514, -2.4565625, -0.33440492, -3.046139...
# 1         1      Key_2  [0.22712025, -0.4364421, 1.3369585, -0.6579707...
# 2         2      Key_3  [0.6093821, 0.2190002, -0.66076785, -1.0249059...
# 3         3      Key_4  [-0.60112315, -0.6009095, 0.15832868, -0.78093...
# 4         4      Key_5  [1.5203121, -0.053287506, 0.6854137, -2.185917...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.56016356, 0.5178568, 0.36164814, -1.343524...
# 9996   9996   Key_9997  [0.92409825, -0.4283643, 0.5214166, 0.8151464,...
# 9997   9997   Key_9998  [0.36512315, -1.5723218, -0.2063717, -2.715109...
# 9998   9998   Key_9999  [-1.5443553, 0.57559586, 0.3154941, -0.5183177...
# 9999   9999  Key_10000  [0.7654836, 0.21708003, 0.2392134, 1.2758167, ...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [1.9358258, -1.2855555, 1.786346, 0.5396923, -...
# 1         1      Key_2  [0.794212, -0.107738145, 1.7672615, 1.2623478,...
# 2         2      Key_3  [1.8874626, 0.6190058, 2.4943902, 2.5214384, -...
# 3         3      Key_4  [3.6402206, -0.10355273, -0.17301741, 2.219848...
# 4         4      Key_5  [0.58044446, -1.2368747, 2.5479217, -0.3667429...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [3.8103647, -1.7354795, 1.3607306, 1.1037319, ...
# 9996   9996   Key_9997  [1.8544065, -0.29334918, 1.5114964, 1.1249355,...
# 9997   9997   Key_9998  [3.0457916, 0.535466, 1.0649995, 0.9179691, -1...
# 9998   9998   Key_9999  [2.4187412, -0.96103114, 3.1528952, 1.3925697,...
# 9999   9999  Key_10000  [2.800414, -1.5302348, 2.1355925, 0.7754059, -...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf211250>, 'model_config_with_seed': {'Vector Size': 100, 'Window': 5, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'd1998b802f', 'nd_norm': np.float64(0.9685490223141822), 'ssmq': np.float64(0.731723055153598), 'summary': {'vector_size': 100, 'algorithm': 'CBOW', 'window': 5, 'epochs': 30, 'seed': 1, 'nd_score': 0.9685490223141822, 'rs_mean_score': 0.35775381511727994, 'fc_score': 0.700611997306615, 'ssmq_score': 0.731723055153598, 'kvc_recall': 0.3927272727272727}}, {'params': {'Vector Size': 100, 'Window': 5, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.3931296556931769), 'rs_mean': np.float64(0.6737038342762981), 'rs_5': 0.6753571428571431, 'rs_10': 0.6649500499500499, 'rs_20': 0.6808043100217014, 'fc': 0.7190816336996337, 'kvc': {'model_score': np.float64(0.04052731632129324), 'avg_proximity_score': np.float64(0.2872727272727273), 'avg_weighted_proximity_score': np.float64(0.04052731632129324), 'total_found_values': 158, 'total_possible_values': 550, 'overall_recall': 0.2872727272727273, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 100, 'Window': 5, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [-0.058583498, -0.30079463, -0.1156357, 0.0551...
# 1         1      Key_2  [0.13290876, -0.03587692, -0.27889827, 0.01426...
# 2         2      Key_3  [-0.16264302, -0.35710558, -0.08561137, 0.1303...
# 3         3      Key_4  [0.17203818, -0.16217019, -0.23939657, -0.0607...
# 4         4      Key_5  [0.04623282, -0.029528867, -0.2554789, 0.37090...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.07040102, -0.32652485, -0.2141748, 0.013885...
# 9996   9996   Key_9997  [0.16838306, -0.026067235, -0.189704, 0.048475...
# 9997   9997   Key_9998  [0.09564933, -0.32222083, -0.29789075, -0.2275...
# 9998   9998   Key_9999  [0.13320652, -0.025596892, -0.15149045, 0.1802...
# 9999   9999  Key_10000  [0.040789388, -0.14737485, -0.35679752, 0.1535...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# ...
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceaf211210>, 'model_config_with_seed': {'Vector Size': 300, 'Window': 10, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '830796d749', 'nd_norm': np.float64(0.37601568354412024), 'ssmq': np.float64(0.5741314582932409), 'summary': {'vector_size': 300, 'algorithm': 'CBOW', 'window': 10, 'epochs': 30, 'seed': 1, 'nd_score': 0.37601568354412024, 'rs_mean_score': 0.8245594519590022, 'fc_score': 0.6937789046674001, 'ssmq_score': 0.5741314582932409, 'kvc_recall': 0.4018181818181818}}, {'params': {'Vector Size': 300, 'Window': 10, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.7040322482501146), 'rs_mean': np.float64(0.6709959643332956), 'rs_5': 0.6510317460317461, 'rs_10': 0.6554095904095903, 'rs_20': 0.7065465565585504, 'fc': 0.7212438791208791, 'kvc': {'model_score': np.float64(0.020702105326577604), 'avg_proximity_score': np.float64(0.22363636363636363), 'avg_weighted_proximity_score': np.float64(0.020702105326577604), 'total_found_values': 123, 'total_possible_values': 550, 'overall_recall': 0.22363636363636363, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 300, 'Window': 10, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [0.020234214, 0.095067695, 0.1465417, 0.068108...
# 1         1      Key_2  [0.11429036, 0.03688638, 0.1532035, 0.04530024...
# 2         2      Key_3  [-0.019943113, 0.08759403, 0.0029257948, -0.13...
# 3         3      Key_4  [0.023755234, 0.29870307, 0.0004964484, 0.0199...
# 4         4      Key_5  [0.23350902, 0.0053429524, -0.09088172, 0.1221...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.1339857, 0.13621569, 0.10487242, 0.17564343...
# 9996   9996   Key_9997  [0.27681372, 0.17994596, 0.2124529, 0.18733343...
# 9997   9997   Key_9998  [-0.012938348, 0.25835553, 0.20429969, 0.20424...
# 9998   9998   Key_9999  [0.279182, 0.060837343, 0.07614093, 0.16883963...
# 9999   9999  Key_10000  [0.023854434, 0.13166624, 0.03697893, 0.289220...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [-0.18137227, -0.25166035, -0.013610498, 0.102...
# 1         1      Key_2  [-0.20735864, -0.10941815, -0.045396764, 0.132...
# 2         2      Key_3  [-0.08346302, -0.047656786, -0.082677, -0.0412...
# 3         3      Key_4  [-0.3821934, 0.019058084, -0.088610694, 0.1157...
# 4         4      Key_5  [-0.05977701, -0.091360256, -0.105828874, -0.0...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.28391072, 0.074526384, -0.03344798, 0.0443...
# 9996   9996   Key_9997  [0.024466563, -0.003928549, -0.1020781, -0.077...
# 9997   9997   Key_9998  [0.022537408, -0.19151358, 0.061338045, 0.0119...
# 9998   9998   Key_9999  [-0.30773392, 0.08784314, -0.049694534, 0.0357...
# 9999   9999  Key_10000  [-0.014033549, -0.077471495, 0.11495109, 0.062...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceadd2cf50>, 'model_config_with_seed': {'Vector Size': 300, 'Window': 10, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': '333738a8ac', 'nd_norm': np.float64(0.7040322482501146), 'ssmq': np.float64(0.6975636892492217), 'summary': {'vector_size': 300, 'algorithm': 'SGNS', 'window': 10, 'epochs': 30, 'seed': 1, 'nd_score': 0.7040322482501146, 'rs_mean_score': 0.6709959643332956, 'fc_score': 0.7212438791208791, 'ssmq_score': 0.6975636892492217, 'kvc_recall': 0.22363636363636363}}, {'params': {'Vector Size': 300, 'Window': 20, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.9433940224767543), 'rs_mean': np.float64(0.7917892469848992), 'rs_5': 0.7839285714285715, 'rs_10': 0.8045454545454543, 'rs_20': 0.7868937149806715, 'fc': 0.7208166691984487, 'kvc': {'model_score': np.float64(0.07041013384307783), 'avg_proximity_score': np.float64(0.38909090909090915), 'avg_weighted_proximity_score': np.float64(0.07041013384307783), 'total_found_values': 214, 'total_possible_values': 550, 'overall_recall': 0.3890909090909091, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 300, 'Window': 20, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [3.5899377, 1.0687325, 6.7237744, -1.6949265, ...
# 1         1      Key_2  [7.0271134, 1.0570564, 3.3449094, -2.4136903, ...
# 2         2      Key_3  [2.507851, -4.3034334, -3.1592386, -7.1006866,...
# 3         3      Key_4  [10.273084, -3.5929587, 4.220415, -9.793059, -...
# 4         4      Key_5  [6.1859865, 5.9716535, 6.700149, 6.1002913, -1...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [12.193341, 1.9274292, 10.004284, -8.318426, -...
# 9996   9996   Key_9997  [3.1513603, 2.4139903, 3.9886758, -4.2253556, ...
# 9997   9997   Key_9998  [6.2214994, -2.1580305, 3.696704, -5.420624, -...
# 9998   9998   Key_9999  [9.498187, 9.567473, 1.1488476, -3.3494315, -2...
# 9999   9999  Key_10000  [5.0859847, -6.8250804, 4.5725837, 0.45121142,...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [-0.82904315, 2.512968, -3.9419458, -2.4519107...
# 1         1      Key_2  [0.40630168, 2.4101667, -0.5222624, -0.2379820...
# 2         2      Key_3  [-5.9175797, 8.585877, 4.7634263, -0.21528782,...
# 3         3      Key_4  [-1.5997258, 4.587458, 2.3616552, 5.711968, 7....
# 4         4      Key_5  [-3.4627166, 2.938009, 2.5624514, 2.8468413, 0...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-3.7075675, -0.9403536, -4.5379605, 7.129207,...
# 9996   9996   Key_9997  [-1.6859428, 3.3105865, -4.8699875, 7.566843, ...
# 9997   9997   Key_9998  [-2.7140489, 8.398136, -2.0561042, 3.5382926, ...
# 9998   9998   Key_9999  [-3.290983, 8.168233, 0.13601667, 3.854097, 4....
# 9999   9999  Key_10000  [-6.113049, 0.7604618, -0.26737785, -1.5130486...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceadd01350>, 'model_config_with_seed': {'Vector Size': 300, 'Window': 20, 'Algorithmus': 'CBOW', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'f708d6904a', 'nd_norm': np.float64(0.9433940224767543), 'ssmq': np.float64(0.8533971191735366), 'summary': {'vector_size': 300, 'algorithm': 'CBOW', 'window': 20, 'epochs': 30, 'seed': 1, 'nd_score': 0.9433940224767543, 'rs_mean_score': 0.7917892469848992, 'fc_score': 0.7208166691984487, 'ssmq_score': 0.8533971191735366, 'kvc_recall': 0.3890909090909091}}, {'params': {'Vector Size': 300, 'Window': 20, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'nd': np.float64(0.8379752491973631), 'rs_mean': np.float64(0.6194367771496561), 'rs_5': 0.5865873015873017, 'rs_10': 0.6099753840930312, 'rs_20': 0.6617476457686352, 'fc': 0.7209017912087912, 'kvc': {'model_score': np.float64(0.031245853835003848), 'avg_proximity_score': np.float64(0.2727272727272727), 'avg_weighted_proximity_score': np.float64(0.031245853835003848), 'total_found_values': 150, 'total_possible_values': 550, 'overall_recall': 0.2727272727272727, 'keys_evaluated': 50, 'topn': 20, 'filter_keys': True, 'max_fetch': 10000, 'interpretation': 'Ungenügend - Keys kodieren ihre Zeilenwerte kaum'}, 'used_sentence_vectors': {'model_info': {'Vector Size': 300, 'Window': 20, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025}, 'data': [(1,       index        key                                             vector  \
# 0         0      Key_1  [0.16270281, 0.0041111275, 0.009967045, -0.153...
# 1         1      Key_2  [0.05309508, -0.004799643, 0.02325679, 0.05891...
# 2         2      Key_3  [0.13581286, 0.09286211, 0.014022499, -0.20394...
# 3         3      Key_4  [0.10859525, 0.15260564, -0.2098009, 0.0175365...
# 4         4      Key_5  [0.09082481, 0.041809827, -0.11247466, 0.06185...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [0.18516093, 0.18180388, -0.06454997, -0.00301...
# 9996   9996   Key_9997  [0.20046598, 0.05414525, -0.08488545, -0.06617...
# 9997   9997   Key_9998  [0.119329855, 0.091099195, -0.07379828, -0.106...
# 9998   9998   Key_9999  [0.073649384, 0.154855, 0.059044287, -0.007837...
# 9999   9999  Key_10000  [0.11700239, 0.082010396, 0.008283973, -0.0705...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns]), (42,       index        key                                             vector  \
# 0         0      Key_1  [0.19087085, 0.04224581, 0.020969626, 0.041413...
# 1         1      Key_2  [0.095705815, -0.06468427, 0.07227313, 0.02626...
# 2         2      Key_3  [0.0945626, -0.032912653, 0.09399772, 0.047821...
# 3         3      Key_4  [-0.012524978, 0.0006826415, 0.09497955, 0.105...
# 4         4      Key_5  [0.028986638, 0.18804292, 0.17012109, 0.116549...
# ...     ...        ...                                                ...
# 9995   9995   Key_9996  [-0.11636267, 0.05125506, 0.12777543, 0.148366...
# 9996   9996   Key_9997  [0.089671105, 0.1472032, 0.056779765, 0.093042...
# 9997   9997   Key_9998  [0.12214132, 0.08499828, 0.11412358, -0.061988...
# 9998   9998   Key_9999  [0.015500394, 0.14463867, 0.058255043, 0.07889...
# 9999   9999  Key_10000  [0.026276963, 0.19773549, -0.008447165, 0.2878...
#
#       churned
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 9995    False
# 9996    False
# 9997     True
# 9998     True
# 9999    False
#
# [10000 rows x 4 columns])]}, 'used_model': {'model_object': <gensim.models.word2vec.Word2Vec object at 0x77ceadbeb250>, 'model_config_with_seed': {'Vector Size': 300, 'Window': 20, 'Algorithmus': 'SGNS', 'Kleinste Worthäufigkeit': 1, 'Workers': 4, 'Epochs': 30, 'Satzanzahl': 10000, 'Satzlänge': 340, 'Negative Sampling': 5, 'Sample': 0, 'Hierarchical Softmax': 0, 'Alpha': 0.025, 'Seed': 1}}, 'experiment_id': 'bf79be9edf', 'nd_norm': np.float64(0.8379752491973631), 'ssmq': np.float64(0.7489990159853366), 'summary': {'vector_size': 300, 'algorithm': 'SGNS', 'window': 20, 'epochs': 30, 'seed': 1, 'nd_score': 0.8379752491973631, 'rs_mean_score': 0.6194367771496561, 'fc_score': 0.7209017912087912, 'ssmq_score': 0.7489990159853366, 'kvc_recall': 0.2727272727272727}}]
# <bound method NDFrame.head of     vector_size  window algorithm      ssmq        nd        rs        fc
# 0            50       2      CBOW  0.419048  0.326512  0.396389  0.684376
# 1            50       2      SGNS  0.494865  0.278790  0.713004  0.707844
# 2            50       5      CBOW  0.382030  0.366010  0.198487  0.697397
# 3            50       5      SGNS  0.362766  0.120848  0.551069  0.685108
# 4            50      10      CBOW  0.588969  0.670440  0.393997  0.677751
# 5            50      10      SGNS  0.294771  0.039281  0.473623  0.665215
# 6            50      20      CBOW  0.865947  1.000000  0.739809  0.720020
# 7            50      20      SGNS  0.277104  0.000000  0.481796  0.662828
# 8           100       2      CBOW  0.519023  0.374351  0.644647  0.692269
# 9           100       2      SGNS  0.585472  0.388014  0.824995  0.719830
# 10          100       5      CBOW  0.731723  0.968549  0.357754  0.700612
# 11          100       5      SGNS  0.542492  0.393130  0.673704  0.719082
# 12          100      10      CBOW  0.581693  0.411169  0.790412  0.694926
# 13          100      10      SGNS  0.449137  0.318806  0.511210  0.681854
# 14          100      20      CBOW  0.851492  0.958116  0.761042  0.720608
# 15          100      20      SGNS  0.385356  0.181342  0.531850  0.675651
# 16          200       2      CBOW  0.507132  0.442227  0.490671  0.694086
# 17          200       2      SGNS  0.596714  0.395737  0.849199  0.720430
# 18          200       5      CBOW  0.532061  0.491538  0.480537  0.710654
# 19          200       5      SGNS  0.560019  0.445023  0.643976  0.721572
# 20          200      10      CBOW  0.607207  0.453150  0.807550  0.691837
# 21          200      10      SGNS  0.648554  0.643317  0.608897  0.721132
# 22          200      20      CBOW  0.839753  0.919700  0.785854  0.720731
# 23          200      20      SGNS  0.597445  0.562195  0.579333  0.712736
# 24          300       2      CBOW  0.495473  0.345868  0.611577  0.695333
# 25          300       2      SGNS  0.601412  0.399941  0.858071  0.720099
# 26          300       5      CBOW  0.543269  0.397231  0.675863  0.709474
# 27          300       5      SGNS  0.574684  0.464266  0.660761  0.721615
# 28          300      10      CBOW  0.574131  0.376016  0.824559  0.693779
# 29          300      10      SGNS  0.697564  0.704032  0.670996  0.721244
# 30          300      20      CBOW  0.853397  0.943394  0.791789  0.720817
# 31          300      20      SGNS  0.748999  0.837975  0.619437  0.720902>

# %% [markdown]
# <h2>Visualisierung<h2>

# %%
import matplotlib.pyplot as plt

df_sorted = df.sort_values("ssmq", ascending=False).reset_index(drop=True)

plt.figure()
plt.bar(
    range(len(df_sorted)),
    df_sorted["ssmq"]
)
plt.xticks(
    range(len(df_sorted)),
    df_sorted["algorithm"] + "_" +
    df_sorted["vector_size"].astype(str) + "_" +
    df_sorted["window"].astype(str),
    rotation=90
)
plt.ylabel("SSMQ")
plt.title("SSMQ Ranking der Word2Vec-Modelle")
plt.tight_layout()
plt.show()

# %%
top5 = df_sorted.head(5)

plt.figure()
plt.bar(range(5), top5["nd"], label="ND (norm)")
plt.bar(range(5), top5["rs"], bottom=top5["nd"], label="RS")
plt.bar(
    range(5),
    top5["fc"],
    bottom=top5["nd"] + top5["rs"],
    label="FC"
)

plt.xticks(
    range(5),
    top5["algorithm"] + "_" +
    top5["vector_size"].astype(str) + "_" +
    top5["window"].astype(str),
    rotation=45
)
plt.ylabel("SSMQ Komponenten")
plt.title("Zerlegung der Top-5 Modelle")
plt.legend()

sgns = df[df["algorithm"] == "SGNS"]

heatmap = sgns.pivot(
    index="window",
    columns="vector_size",
    values="ssmq"
)

plt.figure()
plt.imshow(heatmap.values)
plt.xticks(range(len(heatmap.columns)), heatmap.columns)
plt.yticks(range(len(heatmap.index)), heatmap.index)
plt.colorbar(label="SSMQ")
plt.xlabel("Vector Size")
plt.ylabel("Window Size")
plt.title("SSMQ Heatmap – SGNS")
plt.show()

plt.tight_layout()
plt.show()

cbow = df[df["algorithm"] == "CBOW"]

heatmap_cbow = cbow.pivot(
    index="window",
    columns="vector_size",
    values="ssmq"
)

plt.figure()
plt.imshow(heatmap_cbow.values)
plt.xticks(
    range(len(heatmap_cbow.columns)),
    heatmap_cbow.columns
)
plt.yticks(
    range(len(heatmap_cbow.index)),
    heatmap_cbow.index
)
plt.colorbar(label="SSMQ")
plt.xlabel("Vector Size")
plt.ylabel("Window Size")
plt.title("SSMQ Heatmap – CBOW")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import cm

# Daten vorbereiten
def prepare_kvc_data(test_results):
    kvc_data = []
    for result in test_results:
        params = result['params']
        kvc = result['kvc']
        kvc_data.append({**params, **kvc})
    return pd.DataFrame(kvc_data)

df = prepare_kvc_data(test_results)

# 1. Hauptvisualisierung: Model Score vs. Parameter
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Model Score nach Algorithmus
algorithm_scores = df.groupby('Algorithmus')['model_score'].mean()
axes[0,0].bar(algorithm_scores.index, algorithm_scores.values)
axes[0,0].set_title('Model Score nach Algorithmus')
axes[0,0].set_ylabel('Avg. Weighted Proximity')

# Model Score vs. Vector Size (farbig nach Algorithmus)
for algo in df['Algorithmus'].unique():
    subset = df[df['Algorithmus'] == algo]
    axes[0,1].scatter(subset['Vector Size'], subset['model_score'], 
                     label=algo, alpha=0.6)
axes[0,1].set_title('Model Score vs. Vector Size')
axes[0,1].set_xlabel('Vector Size')
axes[0,1].set_ylabel('Model Score')
axes[0,1].legend()

# Recall vs. Model Score
scatter = axes[0,2].scatter(df['overall_recall'], df['model_score'],
                           c=df['Vector Size'], cmap='viridis', alpha=0.7)
axes[0,2].set_title('Recall vs. Model Score')
axes[0,2].set_xlabel('Overall Recall')
axes[0,2].set_ylabel('Model Score')
plt.colorbar(scatter, ax=axes[0,2], label='Vector Size')

# Heatmap: Vector Size × Window Size
pivot = df.pivot_table(values='model_score', 
                       index='Vector Size', 
                       columns='Window',
                       aggfunc='mean')
im = axes[1,0].imshow(pivot.values, cmap='YlOrRd', aspect='auto')
axes[1,0].set_title('Heatmap: Vector Size × Window')
axes[1,0].set_xlabel('Window Size')
axes[1,0].set_ylabel('Vector Size')
plt.colorbar(im, ax=axes[1,0], label='Model Score')

# Erfolgsquote (Recall) nach Konfiguration
recall_by_config = df.groupby(['Algorithmus', 'Vector Size'])['overall_recall'].mean().unstack()
recall_by_config.plot(kind='bar', ax=axes[1,1])
axes[1,1].set_title('Recall nach Konfiguration')
axes[1,1].set_xlabel('Algorithmus')
axes[1,1].set_ylabel('Average Recall')
axes[1,1].tick_params(axis='x', rotation=45)

# Gefundene vs. Mögliche Werte
axes[1,2].scatter(df['total_possible_values'], df['total_found_values'],
                 c=df['model_score'], cmap='plasma', alpha=0.7, s=50)
axes[1,2].plot([0, df['total_possible_values'].max()], 
              [0, df['total_possible_values'].max()], 
              'r--', alpha=0.5, label='Perfekte Treffer')
axes[1,2].set_title('Gefundene vs. Mögliche Werte')
axes[1,2].set_xlabel('Total Possible Values')
axes[1,2].set_ylabel('Total Found Values')
axes[1,2].legend()

plt.tight_layout()
plt.show()

# %%
def plot_kvc_detailed_analysis(df):
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    
    # 1. Drei Hauptmetriken im Vergleich
    metrics = ['model_score', 'avg_proximity_score', 'overall_recall']
    metric_labels = ['Weighted Proximity', 'Avg Proximity', 'Recall']
    
    x = np.arange(len(df))
    width = 0.25
    
    for i, (metric, label) in enumerate(zip(metrics, metric_labels)):
        axes[0,0].bar(x + i*width, df[metric], width=width, label=label)
    
    axes[0,0].set_title('Vergleich der KVC-Metriken')
    axes[0,0].set_xlabel('Experiment')
    axes[0,0].set_ylabel('Score')
    axes[0,0].legend()
    axes[0,0].set_xticks(x + width)
    axes[0,0].set_xticklabels([f'Exp{i+1}' for i in range(len(df))], rotation=45)
    
    # 2. Korrelationsmatrix der Metriken
    kvc_metrics = ['model_score', 'avg_proximity_score', 'overall_recall',
                   'total_found_values', 'total_possible_values']
    corr_matrix = df[kvc_metrics].corr()
    
    im = axes[0,1].imshow(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1)
    axes[0,1].set_title('Korrelation zwischen KVC-Metriken')
    axes[0,1].set_xticks(range(len(kvc_metrics)))
    axes[0,1].set_yticks(range(len(kvc_metrics)))
    axes[0,1].set_xticklabels(['Model', 'AvgProx', 'Recall', 'Found', 'Possible'], rotation=45)
    axes[0,1].set_yticklabels(['Model', 'AvgProx', 'Recall', 'Found', 'Possible'])
    
    for i in range(len(kvc_metrics)):
        for j in range(len(kvc_metrics)):
            text = axes[0,1].text(j, i, f'{corr_matrix.iloc[i, j]:.2f}',
                                ha="center", va="center", color="white")
    
    plt.colorbar(im, ax=axes[0,1])
    
    # 3. Top 5 Konfigurationen
    top5 = df.nlargest(5, 'model_score')[['Algorithmus', 'Vector Size', 'Window', 
                                         'model_score', 'overall_recall']]
    
    x_pos = np.arange(len(top5))
    axes[1,0].barh(x_pos - 0.15, top5['model_score'], height=0.3, label='Model Score')
    axes[1,0].barh(x_pos + 0.15, top5['overall_recall'], height=0.3, label='Recall')
    axes[1,0].set_yticks(x_pos)
    axes[1,0].set_yticklabels([f"{row['Algorithmus']}\nV{row['Vector Size']} W{row['Window']}" 
                              for _, row in top5.iterrows()])
    axes[1,0].set_xlabel('Score')
    axes[1,0].set_title('Top 5 Konfigurationen')
    axes[1,0].legend()
    
    # 4. Parameter Importance (vereinfacht)
    param_importance = {}
    for param in ['Vector Size', 'Window', 'Epochs', 'Negative Sampling']:
        if param in df.columns:
            correlation = df[param].corr(df['model_score'])
            param_importance[param] = abs(correlation)
    
    axes[1,1].bar(param_importance.keys(), param_importance.values())
    axes[1,1].set_title('Parameter-Korrelation mit Model Score')
    axes[1,1].set_ylabel('Absolute Korrelation')
    axes[1,1].tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()

plot_kvc_detailed_analysis(df)
# Out:
# /usr/local/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def create_interactive_dashboard(df):
    # 3D Scatter Plot
    fig = px.scatter_3d(df, x='Vector Size', y='Window', z='model_score',
                       color='Algorithmus', size='overall_recall',
                       hover_data=['Epochs', 'Negative Sampling', 'total_found_values'],
                       title='3D Visualisierung der KVC-Performance')
    fig.show()
    
    # Parallel Coordinates für Parameter
    fig = px.parallel_coordinates(df,
                                 dimensions=['Vector Size', 'Window', 'Epochs', 
                                           'model_score', 'overall_recall'],
                                 color='model_score',
                                 title='Parallel Coordinates der Konfigurationen')
    fig.show()
    
    # Boxplots nach Algorithmus
    fig = make_subplots(rows=1, cols=2, subplot_titles=('Model Score', 'Recall'))
    
    for i, metric in enumerate(['model_score', 'overall_recall']):
        for algo in df['Algorithmus'].unique():
            subset = df[df['Algorithmus'] == algo][metric]
            fig.add_trace(
                go.Box(y=subset, name=algo, showlegend=(i==0)),
                row=1, col=i+1
            )
    
    fig.update_layout(height=500, title_text="Verteilung nach Algorithmus")
    fig.show()

create_interactive_dashboard(df)

# %%
def generate_summary_report(df):
    print("="*60)
    print("KVC METRIKEN ZUSAMMENFASSUNG")
    print("="*60)
    
    # Beste Konfiguration
    best_idx = df['model_score'].idxmax()
    best = df.loc[best_idx]
    
    print(f"\n📊 BESTE KONFIGURATION:")
    print(f"   Algorithmus: {best['Algorithmus']}")
    print(f"   Vector Size: {best['Vector Size']}")
    print(f"   Window: {best['Window']}")
    print(f"   Model Score: {best['model_score']:.4f}")
    print(f"   Recall: {best['overall_recall']:.2%}")
    print(f"   Interpretation: {best['interpretation']}")
    
    # Statistiken
    print(f"\n📈 STATISTIKEN:")
    print(f"   Durchschnittlicher Model Score: {df['model_score'].mean():.4f}")
    print(f"   Range: [{df['model_score'].min():.4f}, {df['model_score'].max():.4f}]")
    print(f"   Std. Deviation: {df['model_score'].std():.4f}")
    
    # Erfolgsrate nach Interpretation
    print(f"\n🎯 ERFOLGSRATE:")
    for interpret in df['interpretation'].unique():
        count = len(df[df['interpretation'] == interpret])
        perc = count / len(df) * 100
        print(f"   {interpret}: {count} Experimente ({perc:.1f}%)")
    
    # Empfehlungen
    print(f"\n💡 EMPFEHLUNGEN:")
    
    # Check für CBOW vs Skip-Gram
    cbow_avg = df[df['Algorithmus'] == 'CBOW']['model_score'].mean()
    skipgram_avg = df[df['Algorithmus'] == 'Skip-Gram']['model_score'].mean() if 'Skip-Gram' in df['Algorithmus'].values else 0
    
    if cbow_avg > skipgram_avg:
        print(f"   • CBOW performt besser für KVC (Ø {cbow_avg:.4f})")
    else:
        print(f"   • Skip-Gram performt besser für KVC (Ø {skipgram_avg:.4f})")
    
    # Optimaler Vector Size Bereich
    best_vector_sizes = df.nlargest(3, 'model_score')['Vector Size'].unique()
    print(f"   • Optimale Vector Sizes: {', '.join(map(str, best_vector_sizes))}")

generate_summary_report(df)
# Out:
# ============================================================
# KVC METRIKEN ZUSAMMENFASSUNG
# ============================================================
#
# 📊 BESTE KONFIGURATION:
#    Algorithmus: CBOW
#    Vector Size: 200
#    Window: 5
#    Model Score: 0.0968
#    Recall: 41.64%
#    Interpretation: Ungenügend - Keys kodieren ihre Zeilenwerte kaum
#
# 📈 STATISTIKEN:
#    Durchschnittlicher Model Score: 0.0592
#    Range: [0.0207, 0.0968]
#    Std. Deviation: 0.0197
#
# 🎯 ERFOLGSRATE:
#    Ungenügend - Keys kodieren ihre Zeilenwerte kaum: 32 Experimente (100.0%)
#
# 💡 EMPFEHLUNGEN:
#    • CBOW performt besser für KVC (Ø 0.0753)
#    • Optimale Vector Sizes: 200, 100, 300
